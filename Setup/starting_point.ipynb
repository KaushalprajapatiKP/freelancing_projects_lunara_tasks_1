# %%
import pandas as pd

# %%
comps = pd.read_csv("/Users/kaushalprajapati/Downloads/Cursor_task_creation_workflow/Competitions.csv")
comps.shape
# Out:
# (10598, 48)

# %%
slug = "airbnb-price-prediction"
print(comps[comps["Slug"] == slug]["Overview"].to_list()[0])
# Out:
# # Overview
#
# This competition is an in-class competition for the course, "Artificial Intelligence and Machine Learning (Spring 2024)", in Renmin University of China.
#
# The competition is to predict the rental prices for listings on the Airbnb website.
# ----------------------
# # Evaluation
#
# Submissions are evaluated on [Root Mean Squared Error (RMSE)](https://en.wikipedia.org/wiki/Root-mean-square_deviation) between the predicted prices and the observed prices.
#
#
# ## Submission File
# For every listing in the test dataset, the submission file should contain two columns: id and price, i.e. the id and the predicted price for the listing.
#
# The file should contain a header and have the following format:
#
#     id,price
#     13055,110
#     2970,80
#     27364,60
#     etc.
